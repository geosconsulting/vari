# %%
import os
import tempfile

import kornia.augmentation as K
import torch
from torch import nn, optim
from torch.utils.data import DataLoader

from torchgeo.datasets import EuroSAT100
from torchgeo.models import ResNet18_Weights, resnet18

torch.manual_seed(0)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# INFO:numexpr.utils:NumExpr defaulting to 16 threads.

# %%
root = os.path.join(tempfile.gettempdir(), "eurosat100")
dataset = EuroSAT100(root, download=True)

for i in torch.randint(len(dataset), (4,)):
    sample = dataset[i]
    dataset.plot(sample)

# %%
train_dataset = EuroSAT100(root, split="train")
val_dataset = EuroSAT100(root, split="val")
test_dataset = EuroSAT100(root, split="test")
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[5], line 2
#       1 train_dataset = EuroSAT100(root, split="train")
# ----> 2 val_dataset = EuroSAT100(root, split="val")
#       3 test_dataset = EuroSAT100(root, split="test")
#
# File ~/miniconda3/envs/geo-ai/lib/python3.12/site-packages/torchgeo/datasets/eurosat.py:148, in EuroSAT.__init__(self, root, split, bands, transforms, download, checksum)
#     143 self.bands = bands
#     144 self.band_indices = Tensor(
#     145     [self.all_band_names.index(b) for b in bands if b in self.all_band_names]
#     146 ).long()
# --> 148 self._verify()
#     150 valid_fns = set()
#     151 with open(os.path.join(self.root, self.split_filenames[split])) as f:
#
# File ~/miniconda3/envs/geo-ai/lib/python3.12/site-packages/torchgeo/datasets/eurosat.py:195, in EuroSAT._verify(self)
#     189         download_url(
#     190             self.url + self.split_filenames[self.split],
#     191             self.root,
#     192             md5=self.split_md5s[self.split] if self.checksum else None,
#     193         )
#     194     else:
# --> 195         raise DatasetNotFoundError(self)
#     197 # Check image directory
#     198 directory = os.path.join(self.root, self.base_dir)
#
# DatasetNotFoundError: Dataset not found in `root='/tmp/eurosat100'` and `download=False`, either specify a different `root` or use `download=True` to automatically download the dataset.
